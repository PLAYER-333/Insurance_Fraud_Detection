# %% [markdown]
# ![Alternative text](outputs/age_distribution.png)

# %% [markdown]
# ![Alternative text](outputs/approved_distribution.png)

# %% [markdown]
# ![Alternative text](outputs/claim_distribution.png)

# %% [markdown]
# ![Alternative text](outputs/confusion_matrix.png)

# %% [markdown]
# ![Alternative text](outputs/correlation_heatmap.png)

# %% [markdown]
# ![Alternative text](outputs/feature_importance.png)

# %% [markdown]
# ![Alternative text](outputs/fraud_distribution.png)
